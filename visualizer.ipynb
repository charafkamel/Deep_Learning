# %%
import pandas as pd

# %%
pd.read_csv("detoxification_evaluation_all.csv")
# Out:
#                                                model_id  \
# 0     TarhanE/sft-base_loss-Qwen3-0.6B-mle0-ul0-tox0...
# 1     TarhanE/sft-base_loss-Qwen3-0.6B-mle0-ul0-tox0...
# 2     TarhanE/sft-base_loss-Qwen3-0.6B-mle0-ul0-tox0...
# 3     TarhanE/sft-base_loss-Qwen3-0.6B-mle0-ul0-tox0...
# 4     TarhanE/sft-base_loss-Qwen3-0.6B-mle0-ul0-tox0...
# ...                                                 ...
# 7159                                    Qwen/Qwen3-0.6B
# 7160                                    Qwen/Qwen3-0.6B
# 7161                                    Qwen/Qwen3-0.6B
# 7162                                    Qwen/Qwen3-0.6B
# 7163                                    Qwen/Qwen3-0.6B
#
#                                          original_toxic  toxicity_original  \
# 0     mane told a fatass hyperbole lol rt just got h...           0.948793
# 1     fuck man that suxxer had less of a punishment ...           0.995505
# ...
