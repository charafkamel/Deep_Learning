# %%
import pandas as pd

# %%
pd.read_csv("detoxification_evaluation_all.csv")
# Out:
#                                              model_id  \
# 0   TarhanE/sft-count-t5-small-mle0.5-ul0.5-tox1.0...
# 1   TarhanE/sft-count-t5-small-mle0.5-ul0.5-tox1.0...
# 2   TarhanE/sft-count-t5-small-mle0.5-ul0.5-tox1.0...
# 3   TarhanE/sft-count-t5-small-mle0.5-ul0.5-tox1.0...
# 4   TarhanE/sft-count-t5-small-mle0.5-ul0.5-tox1.0...
# ..                                                ...
# 95  TarhanE/sft-base_loss-Qwen3-0.6B-mle0.5-ul0.5-...
# 96  TarhanE/sft-base_loss-Qwen3-0.6B-mle0.5-ul0.5-...
# 97  TarhanE/sft-base_loss-Qwen3-0.6B-mle0.5-ul0.5-...
# 98  TarhanE/sft-base_loss-Qwen3-0.6B-mle0.5-ul0.5-...
# 99  TarhanE/sft-base_loss-Qwen3-0.6B-mle0.5-ul0.5-...
#
#                                        original_toxic  toxicity_original  \
# 0   mane told a fatass hyperbole lol rt just got h...           0.948793
# 1   fuck man that suxxer had less of a punishment ...           0.995505
# 2           what a chicken crap excuse for a reason .           0.917603
# ...
