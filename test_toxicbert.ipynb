# %%
## Imports
#%%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from tqdm import tqdm
import json

#%%
# Load the data
ORIGINAL_DATA_DIR = 'NormVio/original_data'
CLEANED_DATA_DIR = 'NormVio/data'

data = {}
banned_users = []
for subfolder in os.listdir(ORIGINAL_DATA_DIR):
    folder_name = subfolder.split("_")[-1]
    banned_users.append(folder_name)
    data[folder_name] = {}

    labeled_json_data = "0_" + subfolder + ".json"
    file_path = os.path.join(CLEANED_DATA_DIR, labeled_json_data)
    with open(file_path, 'r', encoding='utf-8-sig') as f:
        raw_data = json.load(f)

    # Access the nested labels
    labels = raw_data['data']['labels']
    data[folder_name]["labeled_json_data"] = pd.DataFrame(labels)
    for file in os.listdir(os.path.join(ORIGINAL_DATA_DIR, subfolder)):
        data[folder_name][file] = pd.read_json(os.path.join(ORIGINAL_DATA_DIR, subfolder, file), lines=True)

# %%
from collections import Counter
number_of_data = [len(value.keys()) for key, value in data.items()]
counter = Counter(number_of_data)
counter
# Out:
# Counter({5: 4178})

# %%
USER = "ideon1"

# %%
data[USER]["bad_utterance.jsonl"]
# Out:
#             timestamp    user display_name                         message  \
# 0 2022-08-31 10:32:08  ideon1       ideon1  the CYANDYMYAN IS COMING FOR U
#
#    is_emotes_only emotes                            message_id
# 0           False         c8ba4869-c7f6-48d6-a024-a9af835b275e

# %%
data[USER]["channel_setting.jsonl"]
# Out:
#            started_at timezone  \
# 0 2022-08-31 09:50:29      pst
#
#                                                title      game_name language  \
# 0  TRUMP GETTING OWNED BY THE DOJ ----UKRAINE NUC...  Just Chatting       en
#
#    tag_names  streamer display_name
# 0  [English]  hasanabi     HasanAbi

# %%
data[USER]["single_user_context.jsonl"] ## We can get the ban data from here
# Out:
#             timestamp    user display_name                         message  \
# 0 2022-08-31 10:32:08  ideon1       ideon1  the CYANDYMYAN IS COMING FOR U
# 1 2022-08-31 10:32:13  ideon1          NaN                             NaN
# 2 2022-08-31 10:32:13  ideon1          NaN                             NaN
#
#    is_emotes_only emotes                            message_id   action
# 0             0.0         c8ba4869-c7f6-48d6-a024-a9af835b275e  message
# 1             NaN    NaN                                   NaN      ban
# 2             NaN    NaN                                   NaN      ban

# %%
## select rows where action is ban
#data[USER]["multi_user_context.jsonl"].query("action == 'ban'")
data[USER]["multi_user_context.jsonl"]
# Out:
#               timestamp             user     display_name  \
# 0   2022-08-31 10:30:13      blueseven01      Blueseven01
# 1   2022-08-31 10:30:13  hollywoodconner  HollywoodConner
# 2   2022-08-31 10:30:13       mathew1025       mathew1025
# 3   2022-08-31 10:30:13          mrtripp          mrtripp
# 4   2022-08-31 10:30:13   foxystreamthis   foxystreamthis
# ..                  ...              ...              ...
# 593 2022-08-31 10:32:13      pastadactyl      pastadactyl
# 594 2022-08-31 10:32:13         hasanabi         HasanAbi
# 595 2022-08-31 10:32:13         fossabot         Fossabot
# 596 2022-08-31 10:32:13         hasanabi         HasanAbi
# 597 2022-08-31 10:32:13           ideon1              NaN
#
#                                                message  is_emotes_only emotes  \
# 0                                         widepeepoSad             0.0
# 1    i love you but this looks like actual boomer p...             0.0
# 2                              Would have done better…             0.0
# 3    Maybe this is related to the trump leaks? *Put...             0.0
# 4                             get that froste contract             0.0
# ..                                                 ...             ...    ...
# 593                              Is that austin flying             0.0
# 594  https://twitter.com/hasanthehun/status/1565043...             0.0
# 595  peepoHas Thank you Trismatics for the 5 giftie...             0.0
# 596  https://twitter.com/hasanthehun/status/1565043...             0.0
# 597                                                NaN             NaN    NaN
#
#                                message_id   action
# 0    ddf3f089-457d-4708-bdb5-627602ab4d91  message
# 1    c197a846-3d27-4aa9-a552-161f957a7239  message
# 2    21311aed-0227-480a-8750-814b992b3952  message
# 3    5c53a716-78cb-4e90-a5e0-29da462cb32f  message
# 4    c3511486-3db4-4c43-abff-5cbfe77d5494  message
# ..                                    ...      ...
# 593  75090f5e-c2ab-493d-ad6c-0f36018c897e  message
# 594  8c171262-33a2-417e-91e2-74e5795a5af2  message
# 595  9acd1153-5854-4c31-b1b6-32ae2673b14d  message
# 596  bd9560e0-5613-4888-98e3-78ad0ad07f32  message
# 597                                   NaN      ban
#
# [598 rows x 8 columns]

# %%
data[USER]["labeled_json_data"]
# Out:
#    anotation_id                                step_1       target_1  \
# 0             0                                [판단불가]           None
# 1             1                          [Incivility]           None
# 2             2  [HIB, Mentioning other broadcasters]  [Broadcaster]
#
#                                  step_2       target_2  \
# 0       [Mentioning other broadcasters]           None
# 1       [Mentioning other broadcasters]           None
# 2  [HIB, Mentioning other broadcasters]  [Broadcaster]
#
#                                  step_3       target_3  \
# 0       [Mentioning other broadcasters]           None
# 1       [Mentioning other broadcasters]           None
# 2  [HIB, Mentioning other broadcasters]  [Broadcaster]
#
#                            comment streamer_knowledge twitch_knowledge
# 0                             None               None             None
# 1  [Candy man represents Sam Hyde]               None             None
# 2                             None               None             None

# %%
data["theefinessekidd"].keys()
# Out:
# dict_keys(['labeled_json_data', 'channel_setting.jsonl', 'single_user_context.jsonl', 'multi_user_context.jsonl', 'bad_utterance.jsonl'])

# %%
USER = "agase1"

# %%
data[USER]["bad_utterance.jsonl"]["message"].item()
# Out:
# 'MOD THAT BANNED ME IS GOING TO DIE OF CANCER BEFORE 2023. I KNOW U HERE NOOB'

# %%
data[USER]["labeled_json_data"]
# Out:
#    anotation_id step_1               target_1 step_2               target_2  \
# 0             0  [HIB]  [Others in broadcast]  [HIB]  [Others in broadcast]
# 1             1  [HIB]  [Others in broadcast]  [HIB]  [Others in broadcast]
# 2             2  [HIB]  [Others in broadcast]  [HIB]  [Others in broadcast]
#
#   step_3               target_3          comment streamer_knowledge  \
# 0  [HIB]  [Others in broadcast]             None               None
# 1  [HIB]  [Others in broadcast]             None               None
# 2  [HIB]  [Others in broadcast]  [to moderators]               None
#
#   twitch_knowledge
# 0             None
# 1             None
# 2             None

# %%
import pandas as pd

results = []

for user in data:
    user_data = data[user]

    # Get message and labels
    message = user_data["bad_utterance.jsonl"]["message"].item()
    df = pd.DataFrame(user_data["labeled_json_data"])

    for _, row in df.iterrows():
        steps = [row['step_1'], row['step_2'], row['step_3']]

        # Skip if any step contains "Spesific Language Only"
        if any('Specific Language Only' in label for step in steps for label in step):
            continue

        # Count how many steps contain "HIB"
        hib_count = sum('HIB' in step for step in steps)
        is_hib = 1 if hib_count >= 2 else 0

        results.append({
            'user': user,
            'message': message,
            'is_HIB': is_hib
        })

# Create final DataFrame
final_df = pd.DataFrame(results)

# Group by user and message, then majority vote on is_HIB
final_df = (
    final_df
    .groupby(['user', 'message'], as_index=False)
    .agg(lambda x: 1 if sum(x) >= len(x) / 2 else 0)  # majority voting
)


# Show or save it
print(final_df)
# Out:
#                            user  \
# 0
# 1                             0
# 2                            00
# 3                    000zayn000
# 4                           007
# ...                         ...
# 3927             zvezdaplatinum
# 3928                   zwezwe18
# 3929                     zync94
# 3930                       zyro
# 3931  zzzzzzzzzzzzzzzzzzzzzzzyx
#
#                                                 message  is_HIB
# 0                                             'ffahdfas       0
# 1     ranbooGrass ranbooGrass ranbooGrass ranbooGras...       0
# 2                people still play cs? eww go back 2015       1
# 3                     Candy man caled you out @HasanAbi       0
# 4                             RUUUUUUUUUUUNNNNNNNNNNNNN       0
# ...                                                 ...     ...
# 3927                             mental health OMEGALUL       0
# 3928                                  <message deleted>       0
# 3929  SPACE RTS OMEGALUL SPACE RTS OMEGALUL SPACE RT...       0
# 3930                         @itsjerian stop on YouTube       0
# 3931                        KKonaW most peaceful school       0
#
# [3932 rows x 3 columns]

# %%
final_df.iloc[200:250]
# Out:
#                  user                                            message  \
# 200             aic3e                                     WHATS HER @ YO
# 201     aidentantannn                                             bcneck
# 202        aidsanchex                                             SO BAD
# 203          aikofnbr  is ente 74 cheating btw? im seeing so many rom...
# 204               aim                           save the earth, kill YS?
# 205         aimassist                              Emu taking back shots
# 206           ainul05                                              BOOBA
# 207        aionkasuga            god veibae is sound so hot FeelsDankMan
# 208        airchungus  doctorWTF ????? doctorWTF ????? doctorWTF ????...
# 209                aj                                     apex is better
# 210         ajaa44138  You notice a wall of text in chat and your han...
# 211         ajjgaming                                         BAN ME NOW
# 212          akaggami                                HEKU OH MY Kreygasm
# 213      akashadowsss  xqcGoofy 1ST SPAM xqcGoofy 1ST SPAM xqcGoofy 1...
# 214          akazax23                                              LMAOO
# 215  akitsudoesmath69                                        Face reveal
# 216        akiyama263  forsenLevel forsenLevel forsenLevel forsenLeve...
# 217        akkadian96                 I'm seeing Sam Hyde tomorrow, live
# 218       akmalalthaf            lp mu, kbl x z (( ; b ;;; (! ! m( mjm;(
# 219            akraaa           CiGrip 🚬 ﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞ.
# 220           akspuls  21:37 BloodTrail 21:37 BloodTrail 21:37 BloodT...
# 221          akzhanxd                    Can i also have a sub please?:D
# 222         alanl9608                                        @Sp33K, WOT
# 223        alaynamies                  Candyman called you out thats why
# 224        albarrafim                   i want to sniff kyedae's cockkkk
# 225            albedo                                            BOOBA 🦶
# 226      albert768655                                          blaze.com
# 227       albertocoin                                    lets print some
# 228     albinoblackie                                           fuck you
# 229        albinos686                                         !bet a 400
# 230       alcchemisst  What is he practicing for? Qualifiers next yea...
# 231   alex004pr221212  hate v tubers go check my content oh wait that...
# 232        alexdorf00  Go watch Alexdorf00 stream he is coaching a BE...
# 233         alexg2799                    Did you see Sam Hyde’s callout?
# 234         alexggval                                             im gay
# 235            alexma                        No chori matando al salvaje
# 236     alexodus10000                                         called out
# 237       alexpain200                                      dead streamer
# 238       alfaxxxxxxx                                fight sam you pussy
# 239        alienprogg                                      bing chilling
# 240     aliisontw1tch  LETSGO LETSGO LETSGO HYPERS HYPERS HYPERS LETS...
# 241        alimalik00  ZealsAmbitions https://clips.twitch.tv/Credulo...
# 242         alimoncho  someone told me if i ty sam hyde ill get perma...
# 243           alireno  🐔 BUK BUK BUK 🐔 BUK BUK BUK 🐔 BUK BUK BUK 🐔 BU...
# 244        alistarovv                                              CONOR
# 245       allerbaster  NO STELLARB PepeHands NO STELLARB PepeHands NO...
# 246       alliedallie  SUBprise FORSENLEVEL SUBprise FORSENLEVEL SUBp...
# 247        allsmoke69                                   Looks like erobb
# 248        allycat348  How can ppl be so impatient its an esports eve...
# 249         almirhaha                                               Hola
#
#      is_HIB
# 200       0
# 201       0
# 202       1
# 203       0
# 204       1
# 205       0
# 206       0
# 207       1
# 208       0
# 209       0
# 210       0
# 211       0
# 212       0
# 213       0
# 214       0
# 215       0
# 216       0
# 217       0
# 218       0
# 219       0
# 220       0
# 221       0
# 222       0
# 223       0
# 224       1
# 225       0
# 226       0
# 227       0
# 228       1
# 229       0
# 230       1
# 231       1
# 232       0
# 233       0
# 234       0
# 235       0
# 236       0
# 237       1
# 238       1
# 239       0
# 240       0
# 241       0
# 242       0
# 243       0
# 244       0
# 245       1
# 246       0
# 247       0
# 248       1
# 249       0

# %%
final_df.iloc[248]["message"]
# Out:
# 'How can ppl be so impatient its an esports event, the casters are a vital part'

# %%
hib_counts = final_df['is_HIB'].value_counts()
print(hib_counts)
# Out:
# is_HIB
# 0    2585
# 1    1347
# Name: count, dtype: int64

# %%
rows = []
for user_name, user_data in data.items():
    print(data[user_name].keys())
    ## if message contains emotes, add to the text
    if "bad_utterance.jsonl" not in user_data:
        continue
    if user_data["bad_utterance.jsonl"].emotes[0] != "" or user_data["bad_utterance.jsonl"].emotes[0] != None:
        user_data["bad_utterance.jsonl"]["message"] = user_data["bad_utterance.jsonl"]["message"] + user_data["bad_utterance.jsonl"]["emotes"]
    merged_row = pd.concat([user_data["bad_utterance.jsonl"], user_data["channel_setting.jsonl"].add_prefix('CHANNEL_')], axis=1)

    ## Add the banned data to the row
    banned_date = user_data["multi_user_context.jsonl"].query("action == 'ban'")["timestamp"]
    assert len(banned_date) == 1 ## We should have only 1 banned data
    merged_row["banned_date"] = banned_date.values[0]

    ## Get labels assigned to this message -- steps and status
    all_steps = []
    for key, col in user_data["labeled_json_data"].items():
        if key.startswith("step_"):
            for sublist in col.values:
                if isinstance(sublist, list):
                    all_steps.extend(sublist)
    all_steps = list(set(all_steps))
    merged_row["labels"] = [all_steps]
    merged_row["status"] = "BAN"

    ## Handle context
    input_texts = []

    for i, row in user_data["multi_user_context.jsonl"].iterrows():
        if i == 0:
            input_texts.append(row["message"]+row["emotes"])
        else:
            prev_input = input_texts[i - 1]
            current_msg = row["message"]+row["emotes"]
            input_texts.append(f"{prev_input} [SEP] {current_msg}")

    merged_row["input_text"] = [input_texts]



    rows.append(merged_row)

merged_df = pd.concat(rows, ignore_index=True)
# Out:
# dict_keys(['labeled_json_data', 'channel_setting.jsonl', 'single_user_context.jsonl', 'multi_user_context.jsonl', 'bad_utterance.jsonl'])
# dict_keys(['labeled_json_data', 'channel_setting.jsonl', 'single_user_context.jsonl', 'multi_user_context.jsonl', 'bad_utterance.jsonl'])
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 13
#      11 ## Add the banned data to the row
#      12 banned_date = user_data["multi_user_context.jsonl"].query("action == 'ban'")["timestamp"]
# ---> 13 assert len(banned_date) == 1 ## We should have only 1 banned data
#      14 merged_row["banned_date"] = banned_date.values[0]
#      16 ## Get labels assigned to this message -- steps and status
#
# AssertionError:

# %% [markdown]
# #### Ideas for context handling:
# - **The above code handles input text in a way that mimics real world scenario -- Given a chat history, we add the new text and we try to predict if it is bannable or not**
# - We can add special token to the banned message in the context and try to predict that
# - We can choose a window, and provide the model with this context window
# - We have a list of users who got banned. If a message was sent in a context of a banned message, and the user is not in the users_banned list, then the message is labeled as normal

# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import TextClassificationPipeline

# Load ToxicBERT model and tokenizer
model_name = "unitary/toxic-bert"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Create classification pipeline
pipeline = TextClassificationPipeline(model=model, tokenizer=tokenizer, return_all_scores=True, truncation=True)

def classify_toxicity(text):
    result = pipeline(text)[0]
    return {entry['label']: entry['score'] for entry in result}
    
# Drop or filter out non-strings (like None, float, etc.)
final_df_clean = final_df[final_df['message'].apply(lambda x: isinstance(x, str))].copy()

# Drop duplicates if needed
final_df_unique = final_df_clean.drop_duplicates(subset='message').copy()

# Apply only to unique messages to save time
final_df_unique['toxicity_scores'] = final_df_unique['message'].apply(classify_toxicity)
# Out:
# Device set to use cuda:0
# /opt/jlab-env/lib/python3.12/site-packages/transformers/pipelines/text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
# Define a threshold (e.g., 0.5) to turn the score into a binary prediction
def predict_toxic(score_dict, threshold=0.4):
    return int(score_dict.get('toxic', 0) > threshold)

final_df_unique['predicted_is_HIB'] = final_df_unique['toxicity_scores'].apply(predict_toxic)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Just to be safe, drop missing predictions
eval_df = final_df_unique.dropna(subset=['predicted_is_HIB'])

# Calculate accuracy
accuracy = accuracy_score(eval_df['is_HIB'], eval_df['predicted_is_HIB'])
print(f"Accuracy: {accuracy:.4f}")

# Optional: get precision, recall, F1
print(classification_report(eval_df['is_HIB'], eval_df['predicted_is_HIB']))
# Out:
# Accuracy: 0.7033
#               precision    recall  f1-score   support
#
#            0       0.73      0.87      0.79      2399
#            1       0.63      0.41      0.50      1332
#
#     accuracy                           0.70      3731
#    macro avg       0.68      0.64      0.64      3731
# weighted avg       0.69      0.70      0.69      3731

# %%
final_df_unique.iloc[100:120]
# Out:
#              user                                            message  is_HIB  \
# 100       4ndreja                                         UP HER ASS       1
# 101         4real   What is whit your camera angle ehHmm ehHmm ehHmm       1
# 102            4u                      https://www.twitch.tv/exc6_4u       0
# 103        4xcrit                     https://twitch.tv/anthonytruj3       0
# 104             5  Okayeg WHEN NUB PLAY HEARTHSTONE Okayeg WHEN N...       1
# 105            50  @forsen if they didn't snipe you, you'd legit ...       0
# 106      51kander                              where is bcj his neck       1
# 107           555                    https://www.twitch.tv/monarx226       0
# 108          5678             I’m 11 I don’t have that kind of money       0
# 109     58biotest                                          2 minutes       0
# 110       5chtief  not a hobo PepeHands not a hobo PepeHands not ...       0
# 111  5starjayyyyy  ⣿⣿⡻⠿⣳⠸⢿⡇⢇⣿⡧⢹⠿⣿⣿⣿⣿⣾⣿⡇⣿⣿⣿⣿⡿⡐⣯⠁ ⠄⠄ ⠟⣛⣽⡳⠼⠄⠈⣷⡾⣥⣱⠃⠣⣿...       0
# 112        5tryda                                           FATFECTO       1
# 113            5x                                          ur a noob       1
# 114             6                                                 Ok       0
# 115       603dave              tate is ur content for the next month       0
# 116          6192                                                  u       1
# 117            64                                            weirdos       1
# 118            69                                  Walmart xqc Kappa       0
# 119           690                      Going to actually kill myself       0
#
#                                        toxicity_scores  predicted_is_HIB
# 100  {'toxic': 0.9932814836502075, 'severe_toxic': ...                 1
# 101  {'toxic': 0.47873154282569885, 'severe_toxic':...                 1
# 102  {'toxic': 0.0010975202312693, 'severe_toxic': ...                 0
# 103  {'toxic': 0.0010884564835578203, 'severe_toxic...                 0
# 104  {'toxic': 0.009460250847041607, 'severe_toxic'...                 0
# 105  {'toxic': 0.007933110930025578, 'severe_toxic'...                 0
# 106  {'toxic': 0.187380850315094, 'severe_toxic': 0...                 0
# 107  {'toxic': 0.0009302889811806381, 'severe_toxic...                 0
# 108  {'toxic': 0.0024923982564359903, 'severe_toxic...                 0
# 109  {'toxic': 0.0012580844340845942, 'severe_toxic...                 0
# 110  {'toxic': 0.10625167191028595, 'severe_toxic':...                 0
# 111  {'toxic': 0.11226320266723633, 'severe_toxic':...                 0
# 112  {'toxic': 0.3307953178882599, 'severe_toxic': ...                 0
# 113  {'toxic': 0.9301232099533081, 'severe_toxic': ...                 1
# 114  {'toxic': 0.001176716759800911, 'severe_toxic'...                 0
# 115  {'toxic': 0.0012749205343425274, 'severe_toxic...                 0
# 116  {'toxic': 0.05504892021417618, 'severe_toxic':...                 0
# 117  {'toxic': 0.6669396162033081, 'severe_toxic': ...                 1
# 118  {'toxic': 0.0009595731971785426, 'severe_toxic...                 0
# 119  {'toxic': 0.7646546363830566, 'severe_toxic': ...                 1
