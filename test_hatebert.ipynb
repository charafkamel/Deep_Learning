# %%
## Imports
#%%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from tqdm import tqdm
import json

#%%
# Load the data
ORIGINAL_DATA_DIR = 'original_data'
CLEANED_DATA_DIR = 'data'

data = {}
banned_users = []
for subfolder in os.listdir(ORIGINAL_DATA_DIR):
    folder_name = subfolder.split("_")[-1]
    banned_users.append(folder_name)
    data[folder_name] = {}

    labeled_json_data = "0_" + subfolder + ".json"
    file_path = os.path.join(CLEANED_DATA_DIR, labeled_json_data)
    with open(file_path, 'r', encoding='utf-8-sig') as f:
        raw_data = json.load(f)

    # Access the nested labels
    labels = raw_data['data']['labels']
    data[folder_name]["labeled_json_data"] = pd.DataFrame(labels)
    for file in os.listdir(os.path.join(ORIGINAL_DATA_DIR, subfolder)):
        data[folder_name][file] = pd.read_json(os.path.join(ORIGINAL_DATA_DIR, subfolder, file), lines=True)

# %%
from collections import Counter
number_of_data = [len(value.keys()) for key, value in data.items()]
counter = Counter(number_of_data)
counter
# Out:
# Counter({5: 4178})

# %%
USER = "ideon1"

# %%
data[USER]["bad_utterance.jsonl"]
# Out:
#             timestamp    user display_name                         message  \
# 0 2022-08-31 10:32:08  ideon1       ideon1  the CYANDYMYAN IS COMING FOR U
#
#    is_emotes_only emotes                            message_id
# 0           False         c8ba4869-c7f6-48d6-a024-a9af835b275e

# %%
data[USER]["channel_setting.jsonl"]
# Out:
#            started_at timezone  \
# 0 2022-08-31 09:50:29      pst
#
#                                                title      game_name language  \
# 0  TRUMP GETTING OWNED BY THE DOJ ----UKRAINE NUC...  Just Chatting       en
#
#    tag_names  streamer display_name
# 0  [English]  hasanabi     HasanAbi

# %%
data[USER]["single_user_context.jsonl"] ## We can get the ban data from here
# Out:
#             timestamp    user display_name                         message  \
# 0 2022-08-31 10:32:08  ideon1       ideon1  the CYANDYMYAN IS COMING FOR U
# 1 2022-08-31 10:32:13  ideon1          NaN                             NaN
# 2 2022-08-31 10:32:13  ideon1          NaN                             NaN
#
#    is_emotes_only emotes                            message_id   action
# 0             0.0         c8ba4869-c7f6-48d6-a024-a9af835b275e  message
# 1             NaN    NaN                                   NaN      ban
# 2             NaN    NaN                                   NaN      ban

# %%
## select rows where action is ban
#data[USER]["multi_user_context.jsonl"].query("action == 'ban'")
data[USER]["multi_user_context.jsonl"]
# Out:
#               timestamp             user     display_name  \
# 0   2022-08-31 10:30:13      blueseven01      Blueseven01
# 1   2022-08-31 10:30:13  hollywoodconner  HollywoodConner
# 2   2022-08-31 10:30:13       mathew1025       mathew1025
# 3   2022-08-31 10:30:13          mrtripp          mrtripp
# 4   2022-08-31 10:30:13   foxystreamthis   foxystreamthis
# ..                  ...              ...              ...
# 593 2022-08-31 10:32:13      pastadactyl      pastadactyl
# 594 2022-08-31 10:32:13         hasanabi         HasanAbi
# 595 2022-08-31 10:32:13         fossabot         Fossabot
# 596 2022-08-31 10:32:13         hasanabi         HasanAbi
# 597 2022-08-31 10:32:13           ideon1              NaN
#
#                                                message  is_emotes_only emotes  \
# 0                                         widepeepoSad             0.0
# 1    i love you but this looks like actual boomer p...             0.0
# 2                              Would have done better…             0.0
# 3    Maybe this is related to the trump leaks? *Put...             0.0
# 4                             get that froste contract             0.0
# ..                                                 ...             ...    ...
# 593                              Is that austin flying             0.0
# 594  https://twitter.com/hasanthehun/status/1565043...             0.0
# 595  peepoHas Thank you Trismatics for the 5 giftie...             0.0
# 596  https://twitter.com/hasanthehun/status/1565043...             0.0
# 597                                                NaN             NaN    NaN
#
#                                message_id   action
# 0    ddf3f089-457d-4708-bdb5-627602ab4d91  message
# 1    c197a846-3d27-4aa9-a552-161f957a7239  message
# 2    21311aed-0227-480a-8750-814b992b3952  message
# 3    5c53a716-78cb-4e90-a5e0-29da462cb32f  message
# 4    c3511486-3db4-4c43-abff-5cbfe77d5494  message
# ..                                    ...      ...
# 593  75090f5e-c2ab-493d-ad6c-0f36018c897e  message
# 594  8c171262-33a2-417e-91e2-74e5795a5af2  message
# 595  9acd1153-5854-4c31-b1b6-32ae2673b14d  message
# 596  bd9560e0-5613-4888-98e3-78ad0ad07f32  message
# 597                                   NaN      ban
#
# [598 rows x 8 columns]

# %%
data[USER]["labeled_json_data"]
# Out:
#    anotation_id                                step_1       target_1  \
# 0             0                                [판단불가]           None
# 1             1                          [Incivility]           None
# 2             2  [HIB, Mentioning other broadcasters]  [Broadcaster]
#
#                                  step_2       target_2  \
# 0       [Mentioning other broadcasters]           None
# 1       [Mentioning other broadcasters]           None
# 2  [HIB, Mentioning other broadcasters]  [Broadcaster]
#
#                                  step_3       target_3  \
# 0       [Mentioning other broadcasters]           None
# 1       [Mentioning other broadcasters]           None
# 2  [HIB, Mentioning other broadcasters]  [Broadcaster]
#
#                            comment streamer_knowledge twitch_knowledge
# 0                             None               None             None
# 1  [Candy man represents Sam Hyde]               None             None
# 2                             None               None             None

# %%
data["theefinessekidd"].keys()
# Out:
# dict_keys(['labeled_json_data', 'bad_utterance.jsonl', 'multi_user_context.jsonl', 'channel_setting.jsonl', 'single_user_context.jsonl'])

# %%
USER = "agase1"

# %%
data[USER]["bad_utterance.jsonl"]["message"].item()
# Out:
# 'MOD THAT BANNED ME IS GOING TO DIE OF CANCER BEFORE 2023. I KNOW U HERE NOOB'

# %%
data[USER]["labeled_json_data"]
# Out:
#    anotation_id step_1               target_1 step_2               target_2  \
# 0             0  [HIB]  [Others in broadcast]  [HIB]  [Others in broadcast]
# 1             1  [HIB]  [Others in broadcast]  [HIB]  [Others in broadcast]
# 2             2  [HIB]  [Others in broadcast]  [HIB]  [Others in broadcast]
#
#   step_3               target_3          comment streamer_knowledge  \
# 0  [HIB]  [Others in broadcast]             None               None
# 1  [HIB]  [Others in broadcast]             None               None
# 2  [HIB]  [Others in broadcast]  [to moderators]               None
#
#   twitch_knowledge
# 0             None
# 1             None
# 2             None

# %%
import pandas as pd

results = []

for user in data:
    user_data = data[user]

    # Get message and labels
    message = user_data["bad_utterance.jsonl"]["message"].item()
    df = pd.DataFrame(user_data["labeled_json_data"])

    for _, row in df.iterrows():
        steps = [row['step_1'], row['step_2'], row['step_3']]

        # Skip if any step contains "Spesific Language Only"
        if any('Specific Language Only' in label for step in steps for label in step):
            continue

        # Count how many steps contain "HIB"
        hib_count = sum('HIB' in step for step in steps)
        is_hib = 1 if hib_count >= 2 else 0

        results.append({
            'user': user,
            'message': message,
            'is_HIB': is_hib
        })

# Create final DataFrame
final_df = pd.DataFrame(results)

# Group by user and message, then majority vote on is_HIB
final_df = (
    final_df
    .groupby(['user', 'message'], as_index=False)
    .agg(lambda x: 1 if sum(x) >= len(x) / 2 else 0)  # majority voting
)


# Show or save it
print(final_df)
# Out:
#                            user  \
# 0
# 1                             0
# 2                            00
# 3                    000zayn000
# 4                           007
# ...                         ...
# 3928             zvezdaplatinum
# 3929                   zwezwe18
# 3930                     zync94
# 3931                       zyro
# 3932  zzzzzzzzzzzzzzzzzzzzzzzyx
#
#                                                 message  is_HIB
# 0                               get on some rumbleverse       0
# 1              can you perma ban me plzzzz hasan dadddy       1
# 2                people still play cs? eww go back 2015       1
# 3                     Candy man caled you out @HasanAbi       0
# 4                           today is matchhhhhhhh??????       0
# ...                                                 ...     ...
# 3928                             mental health OMEGALUL       0
# 3929                                  <message deleted>       0
# 3930  SPACE RTS OMEGALUL SPACE RTS OMEGALUL SPACE RT...       0
# 3931                         @itsjerian stop on YouTube       0
# 3932                        KKonaW most peaceful school       0
#
# [3933 rows x 3 columns]

# %%
final_df.iloc[200:250]
# Out:
#                  user                                            message  \
# 200      aglamaanne03  imGlitch Attention! Golden imGlitch Attention!...
# 201      agramcitizen                      @Coldblood06 u stupid or wath
# 202        ahteckkkkk                               EDG = EAT DOG GAMING
# 203             aic3e                                     WHATS HER @ YO
# 204     aidentantannn                                             bcneck
# 205        aidsanchex                                             SO BAD
# 206          aikofnbr  is ente 74 cheating btw? im seeing so many rom...
# 207               aim                           save the earth, kill YS?
# 208         aimassist                              Emu taking back shots
# 209           ainul05                                              BOOBA
# 210        aionkasuga            god veibae is sound so hot FeelsDankMan
# 211        airchungus  doctorWTF ????? doctorWTF ????? doctorWTF ????...
# 212                aj                                     apex is better
# 213         ajaa44138  You notice a wall of text in chat and your han...
# 214         ajjgaming                                         BAN ME NOW
# 215          akaggami                                HEKU OH MY Kreygasm
# 216      akashadowsss  xqcGoofy 1ST SPAM xqcGoofy 1ST SPAM xqcGoofy 1...
# 217          akazax23                                              LMAOO
# 218  akitsudoesmath69                                        Face reveal
# 219        akiyama263  forsenLevel forsenLevel forsenLevel forsenLeve...
# 220        akkadian96                 I'm seeing Sam Hyde tomorrow, live
# 221       akmalalthaf            lp mu, kbl x z (( ; b ;;; (! ! m( mjm;(
# 222            akraaa           CiGrip 🚬 ﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞﱞ.
# 223           akspuls  21:37 BloodTrail 21:37 BloodTrail 21:37 BloodT...
# 224          akzhanxd                    Can i also have a sub please?:D
# 225         alanl9608                                        @Sp33K, WOT
# 226        alaynamies                  Candyman called you out thats why
# 227        albarrafim                   i want to sniff kyedae's cockkkk
# 228            albedo                                            BOOBA 🦶
# 229      albert768655                                          blaze.com
# 230       albertocoin                                    lets print some
# 231     albinoblackie                                           fuck you
# 232        albinos686                                         !bet a 400
# 233       alcchemisst  What is he practicing for? Qualifiers next yea...
# 234   alex004pr221212  hate v tubers go check my content oh wait that...
# 235        alexdorf00  Go watch Alexdorf00 stream he is coaching a BE...
# 236         alexg2799                    Did you see Sam Hyde’s callout?
# 237         alexggval                                             im gay
# 238            alexma                        No chori matando al salvaje
# 239     alexodus10000                                         called out
# 240       alexpain200                                      dead streamer
# 241       alfaxxxxxxx                                fight sam you pussy
# 242        alienprogg                                      bing chilling
# 243     aliisontw1tch  LETSGO LETSGO LETSGO HYPERS HYPERS HYPERS LETS...
# 244        alimalik00  ZealsAmbitions https://clips.twitch.tv/Credulo...
# 245         alimoncho  someone told me if i ty sam hyde ill get perma...
# 246           alireno  🐔 BUK BUK BUK 🐔 BUK BUK BUK 🐔 BUK BUK BUK 🐔 BU...
# 247        alistarovv                                              CONOR
# 248       allerbaster  NO STELLARB PepeHands NO STELLARB PepeHands NO...
# 249       alliedallie  SUBprise FORSENLEVEL SUBprise FORSENLEVEL SUBp...
#
#      is_HIB
# 200       0
# 201       1
# 202       1
# 203       0
# 204       0
# 205       1
# 206       0
# 207       1
# 208       0
# 209       0
# 210       1
# 211       0
# 212       0
# 213       0
# 214       0
# 215       0
# 216       0
# 217       0
# 218       0
# 219       0
# 220       0
# 221       0
# 222       0
# 223       0
# 224       0
# 225       0
# 226       0
# 227       1
# 228       0
# 229       0
# 230       0
# 231       1
# 232       0
# 233       1
# 234       1
# 235       0
# 236       0
# 237       0
# 238       0
# 239       0
# 240       1
# 241       1
# 242       0
# 243       0
# 244       0
# 245       0
# 246       0
# 247       0
# 248       1
# 249       0

# %%
final_df.iloc[248]["message"]
# Out:
# 'NO STELLARB PepeHands NO STELLARB PepeHands NO STELLARB PepeHands NO STELLARB PepeHands NO STELLARB PepeHands NO STELLARB PepeHands NO STELLARB PepeHands'

# %%
hib_counts = final_df['is_HIB'].value_counts()
print(hib_counts)
# Out:
# is_HIB
# 0    2581
# 1    1352
# Name: count, dtype: int64

# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import TextClassificationPipeline
import torch

# Load HateBERT model and tokenizer
model_name = "/home/efe/Desktop/Multires_v2/Deep_Learning/HateBERT_hateval"
device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Create classification pipeline
pipeline = TextClassificationPipeline(model=model, tokenizer=tokenizer, return_all_scores=True, truncation=True,device = "cuda")
label_map = {
    "LABEL_0": "non_hate",
    "LABEL_1": "hate"
}
def classify_toxicity(text):
    result = pipeline(text)[0]
    return {label_map[entry['label']]: entry['score'] for entry in result}

# Drop or filter out non-strings
final_df_clean = final_df[final_df['message'].apply(lambda x: isinstance(x, str))].copy()

# Drop duplicates
final_df_unique = final_df_clean.drop_duplicates(subset='message').copy()

# Apply only to unique messages
final_df_unique['toxicity_scores'] = final_df_unique['message'].apply(classify_toxicity)
# Out:
# /home/efe/Desktop/Multires_v2/.venv/lib/python3.8/site-packages/transformers/pipelines/text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
sample = "Damn nigger."

scores = classify_toxicity(sample)
print(scores)
# Out:
# {'non_hate': 0.8109367489814758, 'hate': 0.18906326591968536}

# %%
print(model.config.id2label)
# Out:
# {0: 'LABEL_0', 1: 'LABEL_1'}

# %%
final_df_unique['toxicity_scores'][40]
# Out:
# {'non_hate': 0.7272173166275024, 'hate': 0.27278268337249756}

# %%
def predict_hate(score_dict, threshold=0.2):
    print(score.get('hate,0'))
    return int(score_dict.get('hate', 0) > threshold)

final_df_unique['predicted_is_hate'] = final_df_unique['toxicity_scores'].apply(predict_hate)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Just to be safe, drop missing predictions
eval_df = final_df_unique.dropna(subset=['predicted_is_HIB'])

# Calculate accuracy
accuracy = accuracy_score(eval_df['is_HIB'], eval_df['predicted_is_HIB'])
print(f"Accuracy: {accuracy:.4f}")

# Optional: get precision, recall, F1
print(classification_report(eval_df['is_HIB'], eval_df['predicted_is_HIB']))
# Out:
# Accuracy: 0.6418
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78      2394
#            1       0.00      0.00      0.00      1336
#
#     accuracy                           0.64      3730
#    macro avg       0.32      0.50      0.39      3730
# weighted avg       0.41      0.64      0.50      3730
# /home/efe/Desktop/Multires_v2/.venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/efe/Desktop/Multires_v2/.venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/efe/Desktop/Multires_v2/.venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
final_df_unique.iloc[100:120]
